# %% [markdown]
# # [LAB-08] 파일 입출력

# %% [markdown]
# ## 1. open 함수의 사용

# %% [markdown]
# ### #01 기본 파일 입출력

# %% [markdown]
# 1. helloworld.txt 파일을 생성하고, 변수의 내용을 기록하기

# %%
# 새로운 파일 생성, 혹은 기존의 파일 열기
# -> 파일 경로와 파일 열기 모드 설정
# -> r : 읽기 모드
#    w : 쓰기 모드 (기존의 내용을 덮어쓴다)
#    a : 추가 모드 (기존의 내용을 유지하고 뒤에 추가)
f = open("helloworld.txt", "w", encoding = 'utf-8')

# 파일에 내용 기록하기
# -> 두 문장을 연달아 한 줄에 기록
# -> 줄바꿈을 원하는 위치에 이스케이프 문자(\n) 사용
f.write("Hello Python!!!\n")
f.write("안녕하세요. 파이썬!!!\n")

# open() 함수를 단독으로 사용할 경우 파일 작업 완료 후 닫기 수행
f.close()

# %% [markdown]
# 2. 파일의 내용을 파이썬 변수에 저장하기

# %%
# 이전 예제에서 생성한 파일을 읽어들이기 위해 연다
# -> 읽기 모드(r) 지정
# -> 인코딩 방식은 저장 방식과 동일하게 지정 (다를 경우 에러)
f = open("helloworld.txt", "r", encoding = 'utf-8')

# 파일의 모든 내용을 한 번에 문자열로 읽어들인다
# -> 아래와 같이 파일의 모든 내용을 변수에 저장한 것과 동일한 효과
#           data = "Hello Python!!!\n안녕하세요. 파이썬!!!"
data = f.read()
print(data)

# open() 함수를 단독으로 사용할 경우 파일 작업 완료 후 닫기를 반드시 수행
f.close()
# Out:
# Hello Python!!!
# 안녕하세요. 파이썬!!!

# %% [markdown]
# ### #02 with 문 기반 파일 입출력

# %% [markdown]
# 1. with 문으로 파일 쓰기

# %%
with open("hellopython.txt", "w", encoding = 'utf-8') as f:
    # with 블록 안에서만 파일 객체 f 가 유효함
    for i in range(1, 10):
        f.write("%d >> " % i)
        f.write("Life is too short, ")
        f.write("you need python\n")

    print("파일 저장이 완료되었습니다.")
# Out:
# 파일 저장이 완료되었습니다.

# %% [markdown]
# 2. with 문으로 파일 읽기

# %%
# 읽기 모드로 파일 객체 생성하기

with open("hellopython.txt", "r", encoding = 'utf-8') as f:
    # 파일의 내용을 변수에 저장함
    data = f.read()
    print(data)
# Out:
# 1 >> Life is too short, you need python
# 2 >> Life is too short, you need python
# 3 >> Life is too short, you need python
# 4 >> Life is too short, you need python
# 5 >> Life is too short, you need python
# 6 >> Life is too short, you need python
# 7 >> Life is too short, you need python
# 8 >> Life is too short, you need python
# 9 >> Life is too short, you need python

# %% [markdown]
# ### #03 파일의 내용을 한 줄씩 읽기

# %%
with open("helloworld.txt", "r", encoding = 'utf-8') as f:
    lines = f.readlines()
    print(lines)
    print("-" * 30)

    # 전체 리스트의 크기 확인
    size = len(lines)
    print("읽어들인 데이터는 총 %d줄 입니다." % size)
    print("-" * 30)

    for item in lines:
        # 읽어들인 데이터에 줄바꿈 문자가 포함되므로 공백 제거 필요
        print( item.strip() )
# Out:
# ['Hello Python!!!\n', '안녕하세요. 파이썬!!!\n']
# ------------------------------
# 읽어들인 데이터는 총 2줄 입니다.
# ------------------------------
# Hello Python!!!
# 안녕하세요. 파이썬!!!
